# %% [markdown]
# !!! Caution !!! These methods and function sets are not mature, still need to check the equations and theory behindit. Now it is only give users a rough idea about Orthonormal Rectangular Polynomials
# Opticspy could provide R1-R15 Orthonormal Rectangular Polynomials for rectangle aperture

# %%
# %matplotlib inline
import opticspy
R = opticspy.zernike_rec.Coefficient(R5=1,R6=0.5,R7=0.2)
R.zernikesurface()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/jwgu/git/opticspy/notebooks/orthonormal_rectangular_polynomial.ipynb Cell 2 line 4
#       <a href='vscode-notebook-cell:/Users/jwgu/git/opticspy/notebooks/orthonormal_rectangular_polynomial.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import opticspy
#       <a href='vscode-notebook-cell:/Users/jwgu/git/opticspy/notebooks/orthonormal_rectangular_polynomial.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> R = opticspy.zernike_rec.Coefficient(R5=1,R6=0.5,R7=0.2)
# ----> <a href='vscode-notebook-cell:/Users/jwgu/git/opticspy/notebooks/orthonormal_rectangular_polynomial.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> R.zernikesurface()
#
# File ~/git/opticspy/opticspy/zernike_rec.py:61, in Coefficient.zernikesurface(self)
#      59 	Z = __zernikecartesian__(self.__coefficients__,a,X,Y)
#      60 	fig = __plt__.figure(figsize=(12, 8), dpi=80)
# ---> 61 	ax = __plt__.axes(projection='3d')
#      62 	surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=__cm__.RdYlGn,
#      63         linewidth=0, antialiased=False, alpha = 0.6)
#      65 	ax.auto_scale_xyz([-1, 1], [-1, 1], [Z.max(), Z.min()])
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:1122, in axes(arg, **kwargs)
#    1120 if arg is None:
#    1121     if pos is None:
# -> 1122         return fig.add_subplot(**kwargs)
#    1123     else:
#    1124         return fig.add_axes(pos, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/figure.py:768, in FigureBase.add_subplot(self, *args, **kwargs)
#     765         args = tuple(map(int, str(args[0])))
#     766     projection_class, pkw = self._process_projection_requirements(
#     767         *args, **kwargs)
# --> 768     ax = projection_class(self, *args, **pkw)
#     769     key = (projection_class, pkw)
#     770 return self._add_axes_internal(ax, key)
#
# File ~/git/opticspy/opticspy/mplot3d/axes3d.py:97, in Axes3D.__init__(self, fig, rect, *args, **kwargs)
#      94     self._shared_z_axes.join(self, sharez)
#      95     self._adjustable = 'datalim'
# ---> 97 Axes.__init__(self, fig, rect,
#      98               frameon=True,
#      99               *args, **kwargs)
#     100 # Disable drawing of axes by base class
#     101 Axes.set_axis_off(self)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:683, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     680 self.set_axisbelow(mpl.rcParams['axes.axisbelow'])
#     682 self._rasterization_zorder = None
# --> 683 self.clear()
#     685 # funcs used to format x and y - fall back on major formatters
#     686 self.fmt_xdata = None
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:1393, in _AxesBase.clear(self)
#    1390 # Act as an alias, or as the superclass implementation depending on the
#    1391 # subclass implementation.
#    1392 if self._subclass_uses_cla:
# -> 1393     self.cla()
#    1394 else:
#    1395     self.__clear()
#
# File ~/git/opticspy/opticspy/mplot3d/axes3d.py:1053, in Axes3D.cla(self)
#    1050 self._autoscaleZon = True
#    1051 self._zmargin = 0
# -> 1053 Axes.cla(self)
#    1055 self.grid(rcParams['axes3d.grid'])
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:1402, in _AxesBase.cla(self)
#    1399 # Act as an alias, or as the superclass implementation depending on the
#    1400 # subclass implementation.
#    1401 if self._subclass_uses_cla:
# -> 1402     self.__clear()
#    1403 else:
#    1404     self.clear()
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:1312, in _AxesBase.__clear(self)
#    1309 self.legend_ = None
#    1310 self.containers = []
# -> 1312 self.grid(False)  # Disable grid on init to use rcParameter
#    1313 self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1314           axis=mpl.rcParams['axes.grid.axis'])
#    1315 props = font_manager.FontProperties(
#    1316     size=mpl.rcParams['axes.titlesize'],
#    1317     weight=mpl.rcParams['axes.titleweight'])
#
# File ~/git/opticspy/opticspy/mplot3d/axes3d.py:1264, in Axes3D.grid(self, b, **kwargs)
#    1262 if len(kwargs) :
#    1263     b = True
# -> 1264 self._draw_grid = cbook._string_to_bool(b)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/_api/__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib.cbook' has no attribute '_string_to_bool'

# %%
R.zernikemap()
# Out:
# 0

# %%
R.psf()
# Out:
# 0

# %%
R.mtf()
# Out:
# 0

# %%
R = opticspy.zernike_rec.Coefficient(R8=1,R9=0.5,R12=0.2)
R.zernikesurface()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/jwgu/git/opticspy/notebooks/orthonormal_rectangular_polynomial.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/Users/jwgu/git/opticspy/notebooks/orthonormal_rectangular_polynomial.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> R = opticspy.zernike_rec.Coefficient(R8=1,R9=0.5,R12=0.2)
# ----> <a href='vscode-notebook-cell:/Users/jwgu/git/opticspy/notebooks/orthonormal_rectangular_polynomial.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> R.zernikesurface()
#
# File ~/git/opticspy/opticspy/zernike_rec.py:61, in Coefficient.zernikesurface(self)
#      59 	Z = __zernikecartesian__(self.__coefficients__,a,X,Y)
#      60 	fig = __plt__.figure(figsize=(12, 8), dpi=80)
# ---> 61 	ax = __plt__.axes(projection='3d')
#      62 	surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=__cm__.RdYlGn,
#      63         linewidth=0, antialiased=False, alpha = 0.6)
#      65 	ax.auto_scale_xyz([-1, 1], [-1, 1], [Z.max(), Z.min()])
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:1122, in axes(arg, **kwargs)
#    1120 if arg is None:
#    1121     if pos is None:
# -> 1122         return fig.add_subplot(**kwargs)
#    1123     else:
#    1124         return fig.add_axes(pos, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/figure.py:768, in FigureBase.add_subplot(self, *args, **kwargs)
#     765         args = tuple(map(int, str(args[0])))
#     766     projection_class, pkw = self._process_projection_requirements(
#     767         *args, **kwargs)
# --> 768     ax = projection_class(self, *args, **pkw)
#     769     key = (projection_class, pkw)
#     770 return self._add_axes_internal(ax, key)
#
# File ~/git/opticspy/opticspy/mplot3d/axes3d.py:97, in Axes3D.__init__(self, fig, rect, *args, **kwargs)
#      94     self._shared_z_axes.join(self, sharez)
#      95     self._adjustable = 'datalim'
# ---> 97 Axes.__init__(self, fig, rect,
#      98               frameon=True,
#      99               *args, **kwargs)
#     100 # Disable drawing of axes by base class
#     101 Axes.set_axis_off(self)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:683, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     680 self.set_axisbelow(mpl.rcParams['axes.axisbelow'])
#     682 self._rasterization_zorder = None
# --> 683 self.clear()
#     685 # funcs used to format x and y - fall back on major formatters
#     686 self.fmt_xdata = None
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:1393, in _AxesBase.clear(self)
#    1390 # Act as an alias, or as the superclass implementation depending on the
#    1391 # subclass implementation.
#    1392 if self._subclass_uses_cla:
# -> 1393     self.cla()
#    1394 else:
#    1395     self.__clear()
#
# File ~/git/opticspy/opticspy/mplot3d/axes3d.py:1053, in Axes3D.cla(self)
#    1050 self._autoscaleZon = True
#    1051 self._zmargin = 0
# -> 1053 Axes.cla(self)
#    1055 self.grid(rcParams['axes3d.grid'])
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:1402, in _AxesBase.cla(self)
#    1399 # Act as an alias, or as the superclass implementation depending on the
#    1400 # subclass implementation.
#    1401 if self._subclass_uses_cla:
# -> 1402     self.__clear()
#    1403 else:
#    1404     self.clear()
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:1312, in _AxesBase.__clear(self)
#    1309 self.legend_ = None
#    1310 self.containers = []
# -> 1312 self.grid(False)  # Disable grid on init to use rcParameter
#    1313 self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1314           axis=mpl.rcParams['axes.grid.axis'])
#    1315 props = font_manager.FontProperties(
#    1316     size=mpl.rcParams['axes.titlesize'],
#    1317     weight=mpl.rcParams['axes.titleweight'])
#
# File ~/git/opticspy/opticspy/mplot3d/axes3d.py:1264, in Axes3D.grid(self, b, **kwargs)
#    1262 if len(kwargs) :
#    1263     b = True
# -> 1264 self._draw_grid = cbook._string_to_bool(b)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/_api/__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib.cbook' has no attribute '_string_to_bool'

# %%
R.zernikemap()
# Out:
# 0

# %%
R.psf()
# Out:
# 0

# %%
R.mtf()
# Out:
# 0
