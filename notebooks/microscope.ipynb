# %% [markdown]
# Real Ray Tracing Example: Microscope. This example is immature. Because an microscope system is a finite conjugate system and it should be defined by NA, etc. But opticspy shows some ability to trace it.

# %%
# %matplotlib inline
from opticspy.ray_tracing import *

# %%
New_Lens = codev.readseq("../opticspy/ray_tracing/CodeV_examples/microscope.seq")
New_Lens.lens_info()
# Out:
# Add wavelength 656.3nm done
# Add wavelength 546.1nm done
# Add wavelength 486.1nm done
# Add field angle:0.0 degree done
# Add field angle:2.0 degree done
# Add field angle:3.8 degree done
# Add surface:  1
# Add surface:  2
# Add surface:  3
# Add surface:  4
# Add surface:  5
# Add surface:  6
# Add surface:  7
# Add surface:  8
# Add surface:  9
# Add surface:  10
# Add surface:  11
# Add surface:  12
# Add surface:  13
# Add surface:  14
# Add surface:  15
# Add surface:  16
# Add surface:  17
# Add surface:  18
# Add surface:  19
# '40XPOWER,0.70NAPLAN-ACHROMAT'
# XF

# %%
New_Lens.FNO = 0.7
New_Lens.refresh_paraxial()
trace.trace_draw_ray(New_Lens)
draw.draw_system(New_Lens)
# Out:
# ------------Calculating EFL---------------
# start surface: 2
# end surface: 18
# Rear Focal Length f': 4.278440939883098
# ---------Calculating Entrance Pupil Position-----------
# STOP Surface 6
# STOP thickness 12.1150406847
# start surface: 2
# end surface: 5
# entrance pupil position EP: 15.200048529221561
# ------------Calculating OAL---------------
# start surface: 2
# end surface: 19
# Overall length: 45.16711353984683
# ------------------start drawing lens system-------------

# %%
analysis.spotdiagram(New_Lens,[1,2,3],[1,2,3],n=12,grid_type='grid')
# Out:
# RMS 0.5694175427857849
# RMS 0.5641276821970026
# RMS 0.5497719971700844
# 0

# %%
analysis.Ray_fan(New_Lens,[1,2,3],[1,2,3])
# Out:
# 0
